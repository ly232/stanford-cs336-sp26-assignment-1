# %% [markdown]
# # Training Loss Plot

# %%
import numpy as np

def plot(losses_file):
    losses = np.load(losses_file)
    # %matplotlib inline
    import matplotlib.pyplot as plt
    plt.plot(losses)
    plt.show()

# %%
losses_file = './tinystories_sample_5M_training_loop_losses.npy'
plot(losses_file)
